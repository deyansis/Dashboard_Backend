# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.naive_bayes import MultinomialNB

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    ConfusionMatrixDisplay
)

# %%
data = {

    "comentario":[
        ...
    ],

    "sentimiento":[
        ...
    ]

}

# %%
data = {

    "comentario": [

        # =========================
        # POSITIVOS (30)
        # =========================

        "Buen servicio municipal",
        "Excelente atención",
        "Muy buena gestión",
        "El alcalde está haciendo un buen trabajo",
        "La obra quedó excelente",
        "Felicitaciones por el nuevo puente",
        "Muy buena iniciativa",
        "Excelente organización",
        "La atención fue rápida",
        "Todo salió muy bien",
        "La municipalidad está mejorando",
        "Buen trabajo del personal",
        "Muy satisfecho con el servicio",
        "La gestión está dando resultados",
        "Excelente proyecto",
        "Se nota el cambio en el distrito",
        "Buen mantenimiento de las calles",
        "Gracias por atender nuestro pedido",
        "El parque quedó muy bonito",
        "Muy buena limpieza pública",
        "La obra fue entregada a tiempo",
        "Excelente apoyo a la población",
        "Muy buena comunicación con los vecinos",
        "Buen trabajo de serenazgo",
        "La atención fue amable",
        "Excelente servicio al ciudadano",
        "La municipalidad respondió rápidamente",
        "Todo funcionó correctamente",
        "Muy buena administración",
        "Gran gestión municipal",

        # =========================
        # NEGATIVOS (30)
        # =========================

        "Pésima atención",
        "Muy mala gestión",
        "No cumplen sus promesas",
        "Las calles siguen abandonadas",
        "El servicio fue muy malo",
        "Nunca responden",
        "Todo está descuidado",
        "Hay demasiada demora",
        "No solucionan los problemas",
        "Mala organización",
        "El alcalde no trabaja",
        "No hacen nada por el distrito",
        "La atención fue pésima",
        "El parque está abandonado",
        "No cumplen con las obras",
        "Mucho desorden en la municipalidad",
        "Pésimo servicio al ciudadano",
        "No existe control",
        "La limpieza pública es deficiente",
        "Todo sigue igual de mal",
        "Prometen mucho y hacen poco",
        "La gestión deja mucho que desear",
        "La obra quedó mal hecha",
        "No atienden los reclamos",
        "Muy mala experiencia",
        "Falta seguridad en el distrito",
        "La municipalidad no responde",
        "Pésimo trabajo",
        "No hay mejoras",
        "La gestión es un fracaso",

        # =========================
        # NEUTRALES (30)
        # =========================

        "La obra continúa",
        "Se publicó un comunicado",
        "Hoy hubo una reunión",
        "Se realizó una actividad",
        "Información compartida",
        "La municipalidad emitió un aviso",
        "Servicio regular",
        "Atención normal",
        "Todo continúa con normalidad",
        "Se inició una campaña",
        "El evento será mañana",
        "Se realizó mantenimiento",
        "Los trabajos continúan",
        "Se inauguró una obra",
        "La actividad fue realizada",
        "Se publicó el cronograma",
        "Hubo una sesión de concejo",
        "La municipalidad informó los resultados",
        "Se desarrolló una capacitación",
        "Continúan los trabajos",
        "Se realizará una inspección",
        "La información fue actualizada",
        "Se anunció una campaña",
        "La obra sigue en ejecución",
        "Todo permanece igual",
        "Sin novedades importantes",
        "La atención fue regular",
        "Comentario informativo",
        "Información institucional",
        "Se emitió un comunicado oficial"

    ],

    "sentimiento": [

        # 30 positivos
        "positivo","positivo","positivo","positivo","positivo",
        "positivo","positivo","positivo","positivo","positivo",
        "positivo","positivo","positivo","positivo","positivo",
        "positivo","positivo","positivo","positivo","positivo",
        "positivo","positivo","positivo","positivo","positivo",
        "positivo","positivo","positivo","positivo","positivo",

        # 30 negativos
        "negativo","negativo","negativo","negativo","negativo",
        "negativo","negativo","negativo","negativo","negativo",
        "negativo","negativo","negativo","negativo","negativo",
        "negativo","negativo","negativo","negativo","negativo",
        "negativo","negativo","negativo","negativo","negativo",
        "negativo","negativo","negativo","negativo","negativo",

        # 30 neutrales
        "neutral","neutral","neutral","neutral","neutral",
        "neutral","neutral","neutral","neutral","neutral",
        "neutral","neutral","neutral","neutral","neutral",
        "neutral","neutral","neutral","neutral","neutral",
        "neutral","neutral","neutral","neutral","neutral",
        "neutral","neutral","neutral","neutral","neutral"
    ]
}

# %%
df = pd.DataFrame(data)

df.head()
# Out:
#                                  comentario sentimiento
# 0                   Buen servicio municipal    positivo
# 1                        Excelente atención    positivo
# 2                         Muy buena gestión    positivo
# 3  El alcalde está haciendo un buen trabajo    positivo
# 4                   La obra quedó excelente    positivo

# %%
X = df["comentario"]

y = df["sentimiento"]

# %%
X_train, X_test, y_train, y_test = train_test_split(

    X,

    y,

    test_size=0.20,

    random_state=42,

    stratify=y

)

# %%
vectorizer = TfidfVectorizer(

    ngram_range=(1,2),

    lowercase=True

)

X_train_vec = vectorizer.fit_transform(

    X_train

)

X_test_vec = vectorizer.transform(

    X_test

)

# %%
modelo = MultinomialNB()

modelo.fit(

    X_train_vec,

    y_train

)
# Out:
# MultinomialNB()

# %%
y_pred = modelo.predict(

    X_test_vec

)

# %%
print("Accuracy")

print(

    accuracy_score(

        y_test,

        y_pred

    )

)

print()

print("Precision")

print(

    precision_score(

        y_test,

        y_pred,

        average="weighted"

    )

)

print()

print("Recall")

print(

    recall_score(

        y_test,

        y_pred,

        average="weighted"

    )

)

print()

print("F1 Score")

print(

    f1_score(

        y_test,

        y_pred,

        average="weighted"

    )

)
# Out:
# Accuracy
# 0.7222222222222222
#
# Precision
# 0.734920634920635
#
# Recall
# 0.7222222222222222
#
# F1 Score
# 0.7253302253302254

# %%
print(

    classification_report(

        y_test,

        y_pred

    )

)
# Out:
#               precision    recall  f1-score   support
#
#     negativo       0.57      0.67      0.62         6
#      neutral       0.80      0.67      0.73         6
#     positivo       0.83      0.83      0.83         6
#
#     accuracy                           0.72        18
#    macro avg       0.73      0.72      0.73        18
# weighted avg       0.73      0.72      0.73        18

# %%
cm = confusion_matrix(

    y_test,

    y_pred,

    labels=[

        "positivo",

        "negativo",

        "neutral"

    ]

)

display = ConfusionMatrixDisplay(

    confusion_matrix=cm,

    display_labels=[

        "Positivo",

        "Negativo",

        "Neutral"

    ]

)

display.plot()

plt.title(

    "Matriz de Confusión"

)

plt.show()

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\SOPORTE\Downloads\tesis-sentimientos\backend
